# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Make the graphs a bit prettier, and bigger
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (15, 7)

# %%
veh_file = 'CMPD Data/2011/2011_Stolen_Vehicle.csv';
veh11_df = pd.read_csv(veh_file)
off_file = 'CMPD Data/2011/2011_Incident.csv';
off11_df = pd.read_csv(off_file)
df11 = pd.merge(veh11_df, off11_df, on='Complaint_No', how = 'left')

# %%
df11
# Out:
#          Complaint_No Vehicle_Year  \
# 0      20110101083000         1998
# 1      20110101085702         2004
# 2      20110101094801         2005
# 3      20110101101300         1998
# 4      20110101110303         2000
# ...               ...          ...
# 10031  20131230113902         1997
# 10032  20131230115600         2005
# 10033  20131230135302
# 10034  20131230144102         2008
# 10035  20131230164702         2000
#
#                                            Vechicle_Make  \
# 0      Dodge                                         ...
# 1      Dodge                                         ...
# 2      Ford                                          ...
# 3      Honda                                         ...
# 4      Honda                                         ...
# ...                                                  ...
# 10031  Honda                                         ...
# 10032  Dodge                                         ...
# ...

# %%
veh_file = 'CMPD Data/2012/2012_Stolen_Vehicle.csv';
veh12_df = pd.read_csv(veh_file)
off_file = 'Data/CMPD Data/2012/2012_Incident.csv';
off12_df = pd.read_csv(off_file)
df12 = pd.merge(veh12_df, off12_df, on='Complaint_No', how = 'left')

# %%
df12
# Out:
#         Complaint_No Vehicle_Year  \
# 0     20120616212404         2004
# 1     20120616212404         2004
# 2     20120617102701         1997
# 3     20120617102701         1997
# 4     20120617153800         1999
# ...              ...          ...
# 8948  20121230104503         2005
# 8949  20121230130200         1977
# 8950  20121230130200         1977
# 8951  20121230193001         2006
# 8952  20121230193001         2006
#
#                                           Vechicle_Make  \
# 0     Buick                                         ...
# 1     Buick                                         ...
# 2     Chrysler                                      ...
# 3     Chrysler                                      ...
# 4     Chevrolet                                     ...
# ...                                                 ...
# 8948  Honda                                         ...
# 8949  Chevrolet                                     ...
# ...

# %%
veh_file = 'CMPD Data/2013/2013_Stolen_Vehicle.csv';
veh13_df = pd.read_csv(veh_file)
off_file = 'CMPD Data/2013/2013_Incident.csv';
off13_df = pd.read_csv(off_file)
df13 = pd.merge(veh13_df, off13_df, on='Complaint_No', how = 'left')

# %%
df13
# Out:
#         Complaint_No Vehicle_Year  \
# 0     20130101152703
# 1     20130101210301         1987
# 2     20130102032300         1998
# 3     20130102065700         2004
# 4     20130102091702         1995
# ...              ...          ...
# 3219  20131230113902         1997
# 3220  20131230115600         2005
# 3221  20131230135302
# 3222  20131230144102         2008
# 3223  20131230164702         2000
#
#                                           Vechicle_Make  \
# 0     Mercury                                       ...
# 1     Nissan                                        ...
# 2     Nissan                                        ...
# 3     Dodge                                         ...
# 4     Dodge                                         ...
# ...                                                 ...
# 3219  Honda                                         ...
# 3220  Dodge                                         ...
# 3221  Dodge                                         ...
# ...

# %%
veh_file = 'CMPD Data/2014/2014_Stolen_Vehicle.csv';
veh14_df = pd.read_csv(veh_file)
off_file = 'CMPD Data/2014/2014_Incident.csv';
off14_df = pd.read_csv(off_file, low_memory=False)
df14 = pd.merge(veh14_df, off14_df, on='Complaint_No', how = 'left')
df14 = df14.drop(["Unnamed: 28", "Unnamed: 29"], axis=1)

# %%
df14.plot(kind='scatter', x='Vehicle_Year', y='Block_No', alpha=0.2)
# Out:
#         Complaint_No Vehicle_Year  \
# 0     20140101025300         2013
# 1     20140101034800         1996
# 2     20140101075101         1991
# 3     20140101083201         2005
# 4     20140101103200         2011
# ...              ...          ...
# 3091  20141230114400         1994
# 3092  20141230162000         2011
# 3093  20141231025501         2003
# 3094  20141231162300
# 3095  20141231233100         2001
#
#                                           Vechicle_Make  \
# 0     Kia Motors                                    ...
# 1     Honda                                         ...
# 2     Chevrolet                                     ...
# 3     Ford                                          ...
# 4     Chevrolet                                     ...
# ...                                                 ...
# 3091  Acura                                         ...
# 3092  Chevrolet                                     ...
# ...

# %%
veh_file = 'CMPD Data/2015/2015_Stolen_Vehicle.csv';
veh15_df = pd.read_csv(veh_file)
off_file = 'CMPD Data/2015/2015_Incident.csv';
off15_df = pd.read_csv(off_file)
df15 = pd.merge(veh15_df, off15_df, on='Complaint_No', how = 'left')

# %%
df15
# Out:
#         Complaint_No Vehicle_Year  \
# 0     20150101001803         2000
# 1     20150101014401         2004
# 2     20150101030601         1972
# 3     20150101030601         1981
# 4     20150101044401         1996
# ...              ...          ...
# 3715  20151231172502         2014
# 3716  20151231184700         1997
# 3717  20151231201302         2001
# 3718  20151231204401
# 3719  20151231210300         2004
#
#                                           Vechicle_Make  \
# 0     Mitsubishi                                    ...
# 1     Pontiac                                       ...
# 2     Chevrolet                                     ...
# 3     Chevrolet                                     ...
# 4     Mercury                                       ...
# ...                                                 ...
# 3715  Ford                                          ...
# 3716  Buick                                         ...
# ...

# %%
veh_file = 'CMPD Data/2016/2016_Stolen_Vehicle.csv';
veh16_df = pd.read_csv(veh_file)
off_file = 'CMPD Data/2016/2016_Incident.csv';
off16_df = pd.read_csv(off_file)
df16 = pd.merge(veh16_df, off16_df, on='Complaint_No', how = 'left')

# %%
df16
# Out:
#         Complaint_No Vehicle_Year  \
# 0     20160101000006         2006
# 1     20160101020804         2000
# 2     20160101022002         2010
# 3     20160101044501         1997
# 4     20160101075200         1998
# ...              ...          ...
# 4583  20161231090302         2014
# 4584  20161231120101         1999
# 4585  20161231163001         2017
# 4586  20161231171500         2006
# 4587  20161231202701         2016
#
#                                           Vechicle_Make  \
# 0     Hyundai                                       ...
# 1     Honda                                         ...
# 2     Ford                                          ...
# 3     Honda                                         ...
# 4     Buick                                         ...
# ...                                                 ...
# 4583  Nissan                                        ...
# 4584  Mercury                                       ...
# ...
